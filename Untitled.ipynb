# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
cars_data=pd.read_csv('Cardetails.csv')
cars_data
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
cars_data.drop(columns=['torque'],inplace=True)

# %%
cars_data.shape
# Out:
# (8128, 12)

# %% [markdown]
# ## Preproccessing

# %%
cars_data.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# seats            221
# dtype: int64

# %%
cars_data.dropna(inplace=True)

# %%
cars_data.shape
# Out:
# (7907, 12)

# %%
cars_data.duplicated().sum()
# Out:
# 1189

# %%
cars_data.drop_duplicates(keep='first',inplace=True)

# %%
cars_data.shape
# Out:
# (6718, 12)

# %%
cars_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6718 entries, 0 to 8125
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6718 non-null   object
#  1   year           6718 non-null   int64
#  2   selling_price  6718 non-null   int64
#  3   km_driven      6718 non-null   int64
#  4   fuel           6718 non-null   object
#  5   seller_type    6718 non-null   object
#  6   transmission   6718 non-null   object
#  7   owner          6718 non-null   object
#  8   mileage        6718 non-null   object
#  9   engine         6718 non-null   object
#  10  max_power      6718 non-null   object
#  11  seats          6718 non-null   float64
# dtypes: float64(1), int64(3), object(8)
# memory usage: 682.3+ KB

# %% [markdown]
# ## Data analysis

# %%
cars_data['name'].unique()
# Out:
# array(['Maruti Swift Dzire VDI', 'Skoda Rapid 1.5 TDI Ambition',
#        'Honda City 2017-2020 EXi', ..., 'Tata Nexon 1.5 Revotorq XT',
#        'Ford Freestyle Titanium Plus Diesel BSIV',
#        'Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV'], dtype=object)

# %%
def get_brand_name(car_name):
    car_name = car_name.split(' ')[0]
    return car_name.strip(' ')

# %%
cars_data['name'] = cars_data['name'].apply(get_brand_name)
cars_data
# Out:
#          name  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8121   Maruti  2013         260000      50000  Petrol  Individual
# 8122  Hyundai  2014         475000      80000  Diesel  Individual
# 8123  Hyundai  2013         320000     110000  Petrol  Individual
# 8124  Hyundai  2007         135000     119000  Diesel  Individual
# 8125   Maruti  2009         382000     120000  Diesel  Individual
#
#      transmission                 owner     mileage   engine   max_power  \
# 0          Manual           First Owner   23.4 kmpl  1248 CC      74 bhp
# ...

# %%
cars_data['mileage'] = cars_data['mileage'].apply(get_brand_name)

# %%
cars_data['engine'] = cars_data['engine'].apply(get_brand_name)

# %%
cars_data['max_power'] = cars_data['max_power'].apply(get_brand_name)

# %%
cars_data.iloc[4933]
# Out:
# name                  Maruti
# year                    2009
# selling_price         175000
# km_driven              67000
# fuel                  Petrol
# seller_type       Individual
# transmission          Manual
# owner            First Owner
# mileage                 18.9
# engine                  1061
# max_power                 67
# seats                    5.0
# Name: 5866, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()

# %%
cars_data['name']=encoder.fit_transform(cars_data['name'])

# %%
cars_data['fuel']=encoder.fit_transform(cars_data['fuel'])

# %%
cars_data['seller_type']=encoder.fit_transform(cars_data['seller_type'])

# %%
cars_data['transmission']=encoder.fit_transform(cars_data['transmission'])

# %%
cars_data['owner']=encoder.fit_transform(cars_data['owner'])

# %%
cars_data.reset_index(inplace=True)

# %%
cars_data.drop(columns='index',inplace=True)

# %%
cars_data
# Out:
#       name  year  selling_price  km_driven  fuel  seller_type  transmission  \
# 0       20  2014         450000     145500     1            1             1
# 1       26  2014         370000     120000     1            1             1
# 2       10  2006         158000     140000     3            1             1
# 3       11  2010         225000     127000     1            1             1
# 4       20  2007         130000     120000     3            1             1
# ...    ...   ...            ...        ...   ...          ...           ...
# 6713    20  2013         260000      50000     3            1             1
# 6714    11  2014         475000      80000     1            1             1
# 6715    11  2013         320000     110000     3            1             1
# 6716    11  2007         135000     119000     1            1             1
# 6717    20  2009         382000     120000     1            1             1
#
#       owner mileage engine max_power  seats
# ...

# %%
df=cars_data.apply(pd.to_numeric)

# %%
df.seats.plot(kind='box')
# Out:
# <Axes: >

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        1
# seats            0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# name             0
# year             0
# selling_price    0
# km_driven        0
# fuel             0
# seller_type      0
# transmission     0
# owner            0
# mileage          0
# engine           0
# max_power        0
# seats            0
# dtype: int64

# %%
input=df.drop(columns=['selling_price'])
target=df['selling_price']

# %%
target
# Out:
# 0       450000
# 1       370000
# 2       158000
# 3       225000
# 4       130000
#          ...
# 6713    260000
# 6714    475000
# 6715    320000
# 6716    135000
# 6717    382000
# Name: selling_price, Length: 6717, dtype: int64

# %%
input
# Out:
#       name  year  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 0       20  2014     145500     1            1             1      0    23.40
# 1       26  2014     120000     1            1             1      2    21.14
# 2       10  2006     140000     3            1             1      4    17.70
# 3       11  2010     127000     1            1             1      0    23.00
# 4       20  2007     120000     3            1             1      0    16.10
# ...    ...   ...        ...   ...          ...           ...    ...      ...
# 6713    20  2013      50000     3            1             1      2    18.90
# 6714    11  2014      80000     1            1             1      2    22.54
# 6715    11  2013     110000     3            1             1      0    18.50
# 6716    11  2007     119000     1            1             1      1    16.80
# 6717    20  2009     120000     1            1             1      0    19.30
#
#       engine  max_power  seats
# ...

# %% [markdown]
# ## Linear Regression

# %%
X_train,X_test,y_train,y_test=train_test_split(input,target,test_size=0.2,random_state=42)

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6597275361174637
